# %%
# %run /u/cmor/jupyter/HP_project/main.ipynb

# %% [markdown]
# # W7-X results

# %%
label   = "High Iota"
t0 = 0
tf = 16

Lx = 104.719

# %cd /raven/u/cmor/jupyter/HP_project/data/w7x_old/hi_npol1
A, gamma_h_1, omega_h_1, d, res_h_1 = transient_damping(plot=None)
# %cd /raven/u/cmor/jupyter/HP_project/data/w7x_old/hi_npol2
A, gamma_h_2, omega_h_2, d, res_h_2 = transient_damping(plot=None)
# %cd /raven/u/cmor/jupyter/HP_project/data/w7x_old/hi_npol3
A, gamma_h_3, omega_h_3, d, res_h_3 = transient_damping(plot=None)
# %cd /raven/u/cmor/jupyter/HP_project/data/w7x_old/hi_npol4
A, gamma_h_4, omega_h_4, d, res_h_4 = transient_damping(plot=None)
# %cd /raven/u/cmor/jupyter/HP_project/data/w7x_old/hi_npol5
A, gamma_h_5, omega_h_5, d, res_h_5 = transient_damping(plot=None)
# %cd /raven/u/cmor/jupyter/HP_project/data/w7x_old/hi_npol6
A, gamma_h_6, omega_h_6, d, res_h_6 = transient_damping(plot=None)

# %cd /raven/u/cmor/jupyter/HP_project/data/w7x_old/li_npol1
A, gamma_l_1, omega_l_1, d, res_l_1 = transient_damping(plot=None)
# %cd /raven/u/cmor/jupyter/HP_project/data/w7x_old/li_npol2
A, gamma_l_2, omega_l_2, d, res_l_2 = transient_damping(plot=None)
# %cd /raven/u/cmor/jupyter/HP_project/data/w7x_old/li_npol3
A, gamma_l_3, omega_l_3, d, res_l_3 = transient_damping(plot=None)
# %cd /raven/u/cmor/jupyter/HP_project/data/w7x_old/li_npol4
A, gamma_l_4, omega_l_4, d, res_l_4 = transient_damping(plot=None)
# %cd /raven/u/cmor/jupyter/HP_project/data/w7x_old/li_npol5
A, gamma_l_5, omega_l_5, d, res_l_5 = transient_damping(plot=None)
# %cd /raven/u/cmor/jupyter/HP_project/data/w7x_old/li_npol6
A, gamma_l_6, omega_l_6, d, res_l_6 = transient_damping(plot=None)


plt.figure()
plt.plot([1, 2, 3, 4, 5, 6], [gamma_h_1, gamma_h_2, gamma_h_3, gamma_h_4, gamma_h_5, gamma_h_6], '-o', label=r"High Iota")
plt.plot([1, 2, 3, 4, 5, 6], [gamma_l_1, gamma_l_2, gamma_l_3, gamma_l_4, gamma_l_5, gamma_l_6], '-o', label=r"Low Iota")
plt.legend()
plt.xlabel(r"\# poloidal turns")
plt.ylabel(r"Transient decay  \ $\gamma \ / \ (c_{s} / a)$")
plt.ylim(ymin=0)
plt.xlim(xmin=0)
plt.savefig("/u/cmor/jupyter/HP_project/figures/w7x_decay_hi-lo_iota.png")
plt.show()
# Out:
# /raven/u/cmor/jupyter/HP_project/data/w7x_old/hi_npol1
# /raven/u/cmor/jupyter/HP_project/data/w7x_old/hi_npol2
# /raven/u/cmor/jupyter/HP_project/data/w7x_old/hi_npol3
# /raven/u/cmor/jupyter/HP_project/data/w7x_old/hi_npol4
# /raven/u/cmor/jupyter/HP_project/data/w7x_old/hi_npol5
# /raven/u/cmor/jupyter/HP_project/data/w7x_old/hi_npol6
# /raven/u/cmor/jupyter/HP_project/data/w7x_old/li_npol1
# /raven/u/cmor/jupyter/HP_project/data/w7x_old/li_npol2
# /raven/u/cmor/jupyter/HP_project/data/w7x_old/li_npol3
# /raven/u/cmor/jupyter/HP_project/data/w7x_old/li_npol4
# /raven/u/cmor/jupyter/HP_project/data/w7x_old/li_npol5
# /raven/u/cmor/jupyter/HP_project/data/w7x_old/li_npol6

# %% [markdown]
# #### Poloidal turns scan of the transient decay for two configurations

# %%
plt.figure()
plt.plot([1, 2, 3, 4, 5, 6], [res_h_1, res_h_2, res_h_3, res_h_4, res_h_5, res_h_6], '-o', label=r"High Iota")
plt.plot([1, 2, 3, 4, 5, 6], [res_l_1, res_l_2, res_l_3, res_l_4, res_l_5, res_l_6], '-o', label=r"Low Iota")
plt.legend()
plt.xlabel(r"\# poloidal turns")
plt.ylabel(r"Residual potential / $\phi_{res} / \phi_{(t=0)}$")
plt.xlim(xmin=0)
plt.hlines(y=0, xmin=0, xmax=7, alpha=0.4, linestyle='dashed')
plt.savefig("/u/cmor/jupyter/HP_project/figures/w7x_residual_hi-lo_iota.png")
plt.show()

# %% [markdown]
# #### Poloidal turns scan of the residual for two configurations

# %%
# %run /u/cmor/jupyter/HP_project/main.ipynb
# %cd /raven/u/cmor/jupyter/HP_project/data/w7x_kjm30/alpha_0_npol_1
label   = "alpha 0, npol 1"
t0 = 0
tf = 11

res = 500

A, gamma_0_1, omega_0_1, d, res_0_1 = transient_damping_scan(plot=None)

# %cd /raven/u/cmor/jupyter/HP_project/data/w7x_kjm30/alpha_0_npol_3
label   = "alpha 0, npol 3"
A, gamma_0_3, omega_0_3, d, res_0_3 = transient_damping_scan(plot=None)

# %cd /raven/u/cmor/jupyter/HP_project/data/w7x_kjm30/alpha_0_npol_5
label   = "alpha 0, npol 5"
A, gamma_0_5, omega_0_5, d, res_0_5 = transient_damping_scan(plot=None)

# %cd /raven/u/cmor/jupyter/HP_project/data/w7x_kjm30/alpha_pi5_npol_1
label   = "alpha pi/5, npol 1"
A, gamma_5_1, omega_5_1, d, res_5_1 = transient_damping_scan(plot=None)

# %cd /raven/u/cmor/jupyter/HP_project/data/w7x_kjm30/alpha_pi5_npol_3
label   = "alpha pi/5, npol 2"
A, gamma_5_3, omega_5_3, d, res_5_3 = transient_damping_scan(plot=None)

# %cd /raven/u/cmor/jupyter/HP_project/data/w7x_kjm30/alpha_pi5_npol_5
label   = "alpha pi/10, npol 3"
A, gamma_5_5, omega_5_5, d, res_5_5 = transient_damping_scan(plot=None)

# %cd /raven/u/cmor/jupyter/HP_project/data/w7x_kjm30/surface_long_time
label   = "surface"
A, gamma_w7x_s, omega_w7x_s, d, res_w7x_s = transient_damping_scan(plot="real")
# Out:
# /raven/u/cmor/jupyter/HP_project/data/w7x_kjm30/alpha_0_npol_1
# /raven/u/cmor/jupyter/HP_project/data/w7x_kjm30/alpha_0_npol_3
# /raven/u/cmor/jupyter/HP_project/data/w7x_kjm30/alpha_0_npol_5
# /raven/u/cmor/jupyter/HP_project/data/w7x_kjm30/alpha_pi5_npol_1
# /raven/u/cmor/jupyter/HP_project/data/w7x_kjm30/alpha_pi5_npol_3
# /raven/u/cmor/jupyter/HP_project/data/w7x_kjm30/alpha_pi5_npol_5
# /raven/u/cmor/jupyter/HP_project/data/w7x_kjm30/surface_long_time

# %%
plt.figure()
plt.plot(kx, gamma_0_1, '-o', label=r"$\alpha:0$, turns:1", linewidth=1.5)
plt.plot(kx, gamma_0_3, '-o', label=r"$\alpha:0$, turns:3", linewidth=1.5)
plt.plot(kx, gamma_0_5, '-o', label=r"$\alpha:0$, turns:5", linewidth=1.5)
plt.plot(kx, gamma_5_1, '-*', label=r"$\alpha:\pi / 5$, turns:1", linewidth=1)
plt.plot(kx, gamma_5_3, '-*', label=r"$\alpha:\pi / 5$, turns:3", linewidth=1)
plt.plot(kx, gamma_5_5, '-*', label=r"$\alpha:\pi / 5$, turns:5", linewidth=1)
plt.plot(kx, gamma_w7x_s, label=r"surface", linewidth=1.5, color='red')
plt.legend()
plt.xlabel(r"Wavenumber $k_{x} \rho_{i}$")
plt.ylabel(r"Transient decay  \ $\gamma \ / \ (c_{s} / a)$")
plt.ylim(ymin=0)
plt.xlim(xmin=0)
plt.savefig("/u/cmor/jupyter/HP_project/figures/w7x_decay_kjm30.png")
plt.show()

# %%
plt.figure()
plt.plot(kx, res_0_1, '-o', label=r"$\alpha:0$, turns:1", linewidth=1.5)
plt.plot(kx, res_0_3, '-o', label=r"$\alpha:0$, turns:3", linewidth=1.5)
plt.plot(kx, res_0_5, '-o', label=r"$\alpha:0$, turns:5", linewidth=1.5)
plt.plot(kx, res_5_1, '-*', label=r"$\alpha:\pi / 5$, turns:1", linewidth=1)
plt.plot(kx, res_5_3, '-*', label=r"$\alpha:\pi / 5$, turns:3", linewidth=1)
plt.plot(kx, res_5_5, '-*', label=r"$\alpha:\pi / 5$, turns:5", linewidth=1)
plt.plot(kx, res_w7x_s, label=r"surface", linewidth=1.5, color='red')
plt.legend()
plt.xlabel(r"Wavenumber $k_{x} \rho_{i}$")
plt.ylabel(r"Residual potential / $\phi_{res} / \phi_{(t=0)}$")
# plt.ylim(ymin=0)
plt.xlim(xmin=0)
plt.hlines(y=0, xmin=0, xmax=7, alpha=0.4, linestyle='dashed')
plt.savefig("/u/cmor/jupyter/HP_project/figures/w7x_residual_kjm30.png")
# plt.xscale("log")
plt.show()

# %%
# %cd /raven/u/cmor/jupyter/HP_project/data/w7x_kjm30/surface
label   = "surface"
plot = 'modulus'
log = False
    
# Start plotting details, label and title
if plot != None:
    plt.figure()
    plt.xlabel('Time units $(a/\\rho_{ti})$')
    plt.ylabel(r"Residual")
    plt.axhline(y=0, color='black', linewidth=2, linestyle='dashed')  # Have a reference of zero
    if plot == 'real':  # Normally you choose the real component
        plt.title(r"{0} Real component")
    if plot == 'modulus':
        plt.title(r"{0} Modulus")

# End plotting details

all_r = []

gam = pylab.loadtxt("timetraceions_0030.dat")

a = np.divide(gam[:, 1], gam[0, 1], out=np.zeros_like(gam[:, 1]),
              where=gam[0, 1] != 0)  # The real component
b = np.divide(gam[:, 2], gam[0, 1], out=np.zeros_like(gam[:, 2]),
              where=gam[0, 1] != 0)  # Imaginary component
E = np.sqrt(a**2 + b**2)  # Modulus

t = gam[:, 0]  # Time

kekke = 100
keeke = len(t)

for n in range(keeke-1, keeke):

    all_r = np.append(all_r, a[n])


    if plot == 'real':
        if log == True:
            plt.yscale('log')
#             plt.plot(t, result.init_fit, label=r"Initial guess")
#             plt.plot(t, result.best_fit, linewidth=2, label=r"Best fit")
#             plt.plot(t, gene_fit(t, A=A_sug, g=g_sug, w=w_sug, d=0), label="Sugama's")
#             plt.plot(t, gene_fit(t, A=A_gao, g=g_gao, w=w_gao, d=0), label="Gao's")
    plt.plot(t, a, label='{0}'.format(Lx_scan))  # , color=color)
    plt.plot(t, b, label='{0}'.format(Lx_scan))  # , color=color)
    if plot == 'modulus':
        if log == True:
            plt.yscale('log')
        plt.plot(t, E, label='{0}'.format(label))  # , color=color)

if plot != None:
    plt.show()
# Out:
# /raven/u/cmor/jupyter/HP_project/data/w7x_kjm30/surface

# %%
# %cd /raven/u/cmor/jupyter/HP_project/data/w7x_kjm30/surface_long_time
label   = "surface"
plot = 'real'
log = False
t0 = 0
tf = 10000
    
# Start plotting details, label and title
if plot != None:
    plt.figure()
    plt.xlabel('Time units $(a/\\rho_{ti})$')
    plt.ylabel(r"Residual")
    plt.axhline(y=0, color='black', linewidth=2, linestyle='dashed')  # Have a reference of zero
    if plot == 'real':  # Normally you choose the real component
        plt.title(r"{0} Real component")
    if plot == 'modulus':
        plt.title(r"{0} Modulus")

# End plotting details

all_r = []

gam = pylab.loadtxt("timetraceions_0007.dat")

a = np.divide(gam[:, 1], gam[0, 1], out=np.zeros_like(gam[:, 1]),
              where=gam[0, 1] != 0)  # The real component
b = np.divide(gam[:, 2], gam[0, 1], out=np.zeros_like(gam[:, 2]),
              where=gam[0, 1] != 0)  # Imaginary component
E = np.sqrt(a**2 + b**2)  # Modulus

t = gam[:, 0]  # Time

if t0 != None:
    ini = (np.abs(t - t0)).argmin()
else:
    ini = (np.abs(t - t[0])).argmin()
if tf != None:
    fin = (np.abs(t - tf)).argmin()
else:
    fin = (np.abs(t - t[-1])).argmin()

mil = (np.abs(t - 500)).argmin()
all_r = np.append(all_r, a[mil])

t_orig = t
a_orig = a

a = a[ini:fin]
E = E[ini:fin]
t = t[ini:fin]

gmodel = lmfit.Model(gene_fit)

pars = gmodel.make_params(A=0.65, g=0.08, w=0.15, d=0.003)

pars['w'].set(min=0, max=0.7)
pars['A'].set(min=0, max=2)
pars['d'].set(min=-np.pi, max=np.pi)

result = gmodel.fit(a, pars, t=t, nan_policy='propagate')

#         print(result.fit_report())
gmodel2 = lmfit.Model(edi_fit)
pars2 = gmodel2.make_params(A=1, g=0.02, w=0.01, d=0, R=0)

#     pars['w'].set(min=0, max=0.7)
#     pars['A'].set(min=0, max=2)
#     pars['d'].set(min=-np.pi, max=np.pi)

result2 = gmodel2.fit(a, pars2, t=t, nan_policy='propagate')

#         print(result.fit_report())

if plot == 'real':
    if log == True:
        plt.yscale('log')
#     plt.plot(t, result.init_fit, label=r"Initial guess")
#     plt.plot(t, result.best_fit, linewidth=2, label=r"Best fit")
    plt.plot(t, a)  # , color=color)
    plt.plot(t, result.best_fit, linewidth=2, label=r"GENE")
    plt.plot(t, result2.best_fit, linewidth=2, label=r"Edi")
#             plt.plot(t, gene_fit(t, A=A_sug, g=g_sug, w=w_sug, d=0), label="Sugama's")
#             plt.plot(t, gene_fit(t, A=A_gao, g=g_gao, w=w_gao, d=0), label="Gao's")
if plot == 'modulus':
    if log == True:
        plt.yscale('log')
    plt.plot(t, E, label='{0}'.format(label))  # , color=color))

if plot != None:
    plt.legend()
    plt.show()
# Out:
# /raven/u/cmor/jupyter/HP_project/data/w7x_kjm30/surface_long_time

# %%
for n in range(100, len(np.diff(a_orig))):
    if np.abs(np.average(np.diff(a_orig[n-5:n+5]))) < 0.00001:
        break
dif = np.diff(a_orig)
plt.figure()
plt.plot(t_orig[10:], np.diff(a_orig[9:]), linewidth=1)
plt.scatter(t_orig[n], dif[n], s=15, c='red')
plt.show()

plt.figure()
plt.plot(t_orig, a_orig, linewidth=1)
plt.scatter(t_orig[n], a_orig[n], s=15, c='red')
plt.show()
# plt.plot(t_orig[10:], a_orig[10:])

# %%
np.average(np.diff(a_orig[n-5:n+5]))
# Out:
# -9.88938335805672e-06

# %%
t_orig[n]
# Out:
# 5061.6

# %%
n
# Out:
# 2109
