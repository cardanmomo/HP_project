# %%
# %run /u/cmor/jupyter/Lissa.ipynb
# plt.style.use('/u/cmor/jupyter/my.mplstyle')
# Out:
# loading successful!

# %%
pwd
# Out:
# '/raven/u/cmor/jupyter/HP_project/flux_tubes'

# %%
# %cd /raven/u/cmor/jupyter/HP_project/flux_tubes/LHD
lhd_a0_npol1 = pylab.loadtxt(r"gist_tube_lhd_s0.25_alpha-0_npol1_nz0256", skiprows=14)
lhd_a0_npol2 = pylab.loadtxt(r"gist_tube_lhd_s0.25_alpha-0_npol2_nz0512", skiprows=14)
lhd_a0_npol3 = pylab.loadtxt(r"gist_tube_lhd_s0.25_alpha-0_npol3_nz0768", skiprows=14)

lhd_a10_npol1 = pylab.loadtxt(r"gist_tube_lhd_s0.25_alpha-pi10_npol1_nz0256", skiprows=14)
lhd_a10_npol2 = pylab.loadtxt(r"gist_tube_lhd_s0.25_alpha-pi10_npol2_nz0512", skiprows=14)
lhd_a10_npol3 = pylab.loadtxt(r"gist_tube_lhd_s0.25_alpha-pi10_npol3_nz0768", skiprows=14)

# lhd_a20_npol1 = pylab.loadtxt(r"gist_tube_lhd_s0.25_alpha-pi20_npol1_nz0256", skiprows=14)
# lhd_a20_npol2 = pylab.loadtxt(r"gist_tube_lhd_s0.25_alpha-pi20_npol2_nz0512", skiprows=14)
# lhd_a20_npol3 = pylab.loadtxt(r"gist_tube_lhd_s0.25_alpha-pi20_npol3_nz0768", skiprows=14)
# Out:
# /raven/u/cmor/jupyter/HP_project/flux_tubes/LHD

# %%
npol = 3
nz = 768
z = np.linspace(np.pi, 0, (nz//2)+1)
z = np.concatenate((-z, z[::-1][1:-1]))
zpol3 = z*npol

npol = 2
nz = 512
z = np.linspace(np.pi, 0, (nz//2)+1)
z = np.concatenate((-z, z[::-1][1:-1]))
zpol2 = z*npol

npol = 1
nz = 256
z = np.linspace(np.pi, 0, (nz//2)+1)
z = np.concatenate((-z, z[::-1][1:-1]))
zpol1 = z*npol

# %%
fig = plt.figure()
plt.plot(zpol3, lhd_a0_npol3[:, 3], linewidth=1, label='npol=3, nz0=768')
plt.plot(zpol2, lhd_a0_npol2[:, 3], linewidth=1, label='npol=2, nz0=512')
plt.plot(zpol1, lhd_a0_npol1[:, 3], linewidth=1, label='npol=1, nz0=256')
plt.legend()
plt.xlabel(r"Toroidal angle $(\phi)$")
plt.ylabel(r"Magnetic field $(B)$")
plt.title(r"LHD, alpha=0")
plt.show()

# %%
fig = plt.figure()
plt.plot(zpol3, lhd_a10_npol3[:, 3], linewidth=1, label='npol=3, nz0=768')
plt.plot(zpol2, lhd_a10_npol2[:, 3], linewidth=1, label='npol=2, nz0=512')
plt.plot(zpol1, lhd_a10_npol1[:, 3], linewidth=1, label='npol=1, nz0=256')
plt.legend()
plt.xlabel(r"Toroidal angle $(\phi)$")
plt.ylabel(r"Magnetic field $(B)$")
plt.title(r"LHD, alpha=pi/10")
plt.show()

# %%
fig = plt.figure()
plt.plot(zpol3, lhd_a20_npol3[:, 3], linewidth=1, label='npol=3, nz0=768')
plt.plot(zpol2, lhd_a20_npol2[:, 3], linewidth=1, label='npol=2, nz0=512')
plt.plot(zpol1, lhd_a20_npol1[:, 3], linewidth=1, label='npol=1, nz0=256')
plt.legend()
plt.xlabel(r"Toroidal angle $(\phi)$")
plt.ylabel(r"Magnetic field $(B)$")
plt.title(r"LHD, alpha=pi/20")
plt.show()

# %%
npol = 3
nz = 256
z = np.linspace(np.pi, 0, (nz//2)+1)
z = np.concatenate((-z, z[::-1][1:-1]))
zpol3 = z*npol

npol = 2
nz = 256
z = np.linspace(np.pi, 0, (nz//2)+1)
z = np.concatenate((-z, z[::-1][1:-1]))
zpol2 = z*npol

npol = 1
nz = 256
z = np.linspace(np.pi, 0, (nz//2)+1)
z = np.concatenate((-z, z[::-1][1:-1]))
zpol1 = z*npol

fig = plt.figure()
plt.plot(zpol3, lhd_a0_npol3_256[:, 3], linewidth=1, label='npol=3')
plt.plot(zpol2, lhd_a0_npol2_256[:, 3], linewidth=1, label='npol=2')
plt.plot(zpol1, lhd_a0_npol1_256[:, 3], linewidth=1, label='npol=1')
plt.legend()
plt.xlabel(r"Toroidal angle $(\phi)$")
plt.ylabel(r"Magnetic field $(B)$")
plt.title(r"LHD, alpha=0, nz0=256")
plt.show()
