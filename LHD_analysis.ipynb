# %%
# %run /u/cmor/jupyter/HP_project/main.ipynb

# %% [markdown]
# # LHD linear ZF results

# %%
# %cd /raven/u/cmor/jupyter/HP_project/data/LHD/alpha_0_npol_1
label   = "alpha 0, npol 1"
t0 = 0
tf = 11
res = 500

A, gamma_0_1, omega_0_1, d, res_0_1 = transient_damping_scan(plot=None)

# %cd /raven/u/cmor/jupyter/HP_project/data/LHD/alpha_0_npol_2
label   = "alpha 0, npol 2"
A, gamma_0_2, omega_0_2, d, res_0_2 = transient_damping_scan(plot=None)

# %cd /raven/u/cmor/jupyter/HP_project/data/LHD/alpha_0_npol_3
label   = "alpha 0, npol 3"
A, gamma_0_3, omega_0_3, d, res_0_3 = transient_damping_scan(plot=None)

# %cd /raven/u/cmor/jupyter/HP_project/data/LHD/alpha_pi.10_npol_1
label   = "alpha pi/10, npol 1"
A, gamma_10_1, omega_10_1, d, res_10_1 = transient_damping_scan(plot=None)

# %cd /raven/u/cmor/jupyter/HP_project/data/LHD/alpha_pi.10_npol_2
label   = "alpha pi/10, npol 2"
A, gamma_10_2, omega_10_2, d, res_10_2 = transient_damping_scan(plot=None)

# %cd /raven/u/cmor/jupyter/HP_project/data/LHD/alpha_pi.10_npol_3
label   = "alpha pi/10, npol 3"
A, gamma_10_3, omega_10_3, d, res_10_3 = transient_damping_scan(plot=None)

# %cd /raven/u/cmor/jupyter/HP_project/data/LHD/alpha_pi.20_npol_3
label   = "alpha pi/20, npol 3"
A, gamma_20_3, omega_20_3, d, res_20_3 = transient_damping_scan(plot=None)

# %cd /raven/u/cmor/jupyter/HP_project/data/LHD/surface
label   = "surface"
A, gamma_lhd_s, omega_lhd_s, d, res_lhd_s = transient_damping_scan(plot='real')
# Out:
# /raven/u/cmor/jupyter/HP_project/data/LHD/alpha_0_npol_1
# /raven/u/cmor/jupyter/HP_project/data/LHD/alpha_0_npol_2
# /raven/u/cmor/jupyter/HP_project/data/LHD/alpha_0_npol_3
# /raven/u/cmor/jupyter/HP_project/data/LHD/alpha_pi.10_npol_1
# /raven/u/cmor/jupyter/HP_project/data/LHD/alpha_pi.10_npol_2
# /raven/u/cmor/jupyter/HP_project/data/LHD/alpha_pi.10_npol_3
# /raven/u/cmor/jupyter/HP_project/data/LHD/alpha_pi.20_npol_3
# /raven/u/cmor/jupyter/HP_project/data/LHD/surface

# %%
plt.figure()
plt.plot(kx, gamma_0_1, '-o', label=r"$\alpha:0$, turns:1", linewidth=1.5)
plt.plot(kx, gamma_0_2, '-o', label=r"$\alpha:0$, turns:2", linewidth=1.5)
plt.plot(kx, gamma_0_3, '-o', label=r"$\alpha:0$, turns:3", linewidth=1.5)
plt.plot(kx, gamma_10_1, '-*', label=r"$\alpha:\pi / 10$, turns:1", linewidth=1)
plt.plot(kx, gamma_10_2, '-*', label=r"$\alpha:\pi / 10$, turns:2", linewidth=1)
plt.plot(kx, gamma_10_3, '-*', label=r"$\alpha:\pi / 10$, turns:3", linewidth=1)
plt.plot(kx, gamma_lhd_s, label=r"surface", linewidth=1.5, color='red')
plt.legend()
plt.xlabel(r"Wavenumber $k_{x} \rho_{i}$")
plt.ylabel(r"Transient decay  \ $\gamma \ / \ (c_{s} / a)$")
plt.ylim(ymin=0)
plt.xlim(xmin=0)
plt.savefig("/u/cmor/jupyter/HP_project/figures/lhd_decay.png")
plt.show()

# %% [markdown]
# #### k_x scan of the transient decay rate in the LHD configuration at one alpha with 1, 2 and 3 poloidal turns

# %%
plt.figure()
plt.plot(kx, res_0_1, '-o', label=r"$\alpha:0$, turns:1", linewidth=1.5)
plt.plot(kx, res_0_2, '-o', label=r"$\alpha:0$, turns:2", linewidth=1.5)
plt.plot(kx, res_0_3, '-o', label=r"$\alpha:0$, turns:3", linewidth=1.5)
plt.plot(kx, res_10_1, '-*', label=r"$\alpha:\pi / 10$, turns:1", linewidth=1)
plt.plot(kx, res_10_2, '-*', label=r"$\alpha:\pi / 10$, turns:2", linewidth=1)
plt.plot(kx, res_10_3, '-*', label=r"$\alpha:\pi / 10$, turns:3", linewidth=1)
# plt.plot(kx, res_20_3, '-*', label=r"$\alpha:\pi / 20$, turns:3", linewidth=1)
plt.plot(kx, res_lhd_s, label=r"surface", linewidth=1.5, color='red')
plt.legend(loc='lower right')
plt.xlabel(r"Wavenumber $k_{x} \rho_{i}$")
plt.ylabel(r"Residual potential / $\phi_{res} / \phi_{(t=0)}$")
plt.ylim(ymin=0)
plt.xlim(xmin=0)
plt.savefig("/u/cmor/jupyter/HP_project/figures/lhd_residual.png")
plt.show()

# %% [markdown]
# #### k_x scan of residual in the LHD configuration at one alpha with 1, 2 and 3 poloidal turns

# %%
plt.figure()
plt.scatter(kx, gamma_10_1, label=r"$\alpha:\pi/10$, turns:1")
plt.scatter(kx, gamma_10_2, label=r"$\alpha:\pi/10$, turns:2")
plt.scatter(kx, gamma_10_3, label=r"$\alpha:\pi/10$, turns:3")
plt.legend()
plt.xlabel(r"Wavenumber $k_{x} \rho_{i}$")
plt.ylabel(r"Transient decay  \ $\gamma \ / \ (c_{s} / a)$")
plt.ylim(ymin=0)
plt.xlim(xmin=0)
plt.show()

# %% [markdown]
# #### k_x scan of the transient decay rate in the LHD configuration at one alpha (pi/10) with 1, 2 and 3 poloidal turns

# %%
plt.figure()
plt.scatter(kx, res_10_1, label=r"$\alpha:\pi/10$, turns:1")
plt.scatter(kx, res_10_2, label=r"$\alpha:\pi/10$, turns:2")
plt.scatter(kx, res_10_3, label=r"$\alpha:\pi/10$, turns:3")
plt.legend()
plt.xlabel(r"Wavenumber $k_{x} \rho_{i}$")
plt.ylabel(r"Residual potential / $\phi_{res} / \phi_{(t=0)}$")
plt.ylim(ymin=0)
plt.xlim(xmin=0)
plt.show()

# %% [markdown]
# #### k_x scan of residual in the LHD configuration at one alpha (pi/10) with 1, 2 and 3 poloidal turns

# %%
plt.figure()
plt.scatter(kx, res_0_2, label=r"$\alpha:0$, turns:2")
plt.scatter(kx, res_10_2, label=r"$\alpha:\pi$/10, turns:2")
plt.legend()
plt.xlabel(r"Wavenumber $k_{x} \rho_{i}$")
plt.ylabel(r"Residual potential / $\phi_{res} / \phi_{(t=0)}$")
plt.ylim(ymin=0)
plt.xlim(xmin=0)
plt.show()

# %% [markdown]
# #### Comparison of the residual scan at two different alphas, both at 2 poloidal turns

# %%
plt.figure()
plt.scatter(kx, gamma_0_3, label=r"$\alpha:0$, turns:3")
plt.scatter(kx, gamma_10_3, label=r"$\alpha:\pi/10$, turns:3")
plt.scatter(kx, gamma_20_3, label=r"$\alpha:\pi/20$, turns:3")
plt.legend()
plt.xlabel(r"Wavenumber $k_{x} \rho_{i}$")
plt.ylabel(r"Transient decay  \ $\gamma \ / \ (c_{s} / a)$")
plt.ylim(ymin=0)
plt.xlim(xmin=0)
plt.show()

# %% [markdown]
# #### Comparison of the transient decay for three different angles, at 3 poloidal turns

# %%
plt.figure()
plt.scatter(kx, res_0_3, label=r"$\alpha:0$, turns:3")
plt.scatter(kx, res_10_3, label=r"$\alpha:\pi/10$, turns:3")
plt.scatter(kx, res_20_3, label=r"$\alpha:\pi/20$, turns:3")
plt.legend()
plt.xlabel(r"Wavenumber $k_{x} \rho_{i}$")
plt.ylabel(r"Residual potential / $\phi_{res} / \phi_{(t=0)}$")
plt.ylim(ymin=0)
plt.xlim(xmin=0)
plt.show()

# %% [markdown]
# # Growth rates

# %%
def reader():
    global filename

    data = [ (pylab.loadtxt("{0}".format(filename))) ][0]
    k = data[:, 1]
    g = data[:, 2]
    w = data[:, 3]

    return k, g

# %%
# %cd /raven/u/cmor/jupyter/HP_project/data/LHD/growth
filename = 'kyscanalpha0npol1.txt'
k_a_0_p_1, g_a_0_p_1 = reader()

filename = 'kyscanalpha0npol2.txt'
k_a_0_p_2, g_a_0_p_2 = reader()

filename = 'kyscanalpha0npol3.txt'
k_a_0_p_3, g_a_0_p_3 = reader()

filename = 'kyscanalphapiover10npol1.txt'
k_a_10_p_1, g_a_10_p_1 = reader()

filename = 'kyscanalphapiover10npol2.txt'
k_a_10_p_2, g_a_10_p_2 = reader()

filename = 'kyscanalphapiover10npol3.txt'
k_a_10_p_3, g_a_10_p_3 = reader()
# Out:
# /raven/u/cmor/jupyter/HP_project/data/LHD/growth

# %%
plt.figure()
plt.plot(k_a_0_p_1, g_a_0_p_1, '-o', label=r"$\alpha:0$, turns:1", linewidth=1.5)
plt.plot(k_a_0_p_2, g_a_0_p_2, '-o', label=r"$\alpha:0$, turns:2", linewidth=1.5)
plt.plot(k_a_0_p_3, g_a_0_p_3, '-o', label=r"$\alpha:0$, turns:3", linewidth=1.5)
plt.plot(k_a_10_p_1, g_a_10_p_1, '-*', label=r"$\alpha:\pi / 10$, turns:1", linewidth=1)
plt.plot(k_a_10_p_2, g_a_10_p_2, '-*', label=r"$\alpha:\pi / 10$, turns:2", linewidth=1)
plt.plot(k_a_10_p_3, g_a_10_p_3, '-*', label=r"$\alpha:\pi / 10$, turns:3", linewidth=1)
plt.hlines(y=0.258, xmin=0, xmax=2.5, alpha=0.7, linewidth=1.5, color="red", label="Surface")
plt.xlabel(r"Wavenumber  \ $k_{y} \rho_{i}$")
plt.ylabel(r"Growth rate  \  \ $\gamma \ (c_s / a)$")
plt.legend(loc="right")
plt.ylim(ymin=0)
plt.xlim(xmin=0)
plt.savefig("/u/cmor/jupyter/HP_project/figures/lhd_growth_rates.png")
plt.show()
